# %% [markdown]
# <a href="https://colab.research.google.com/github/Sravani-939/genai-training-tasks/blob/main/SentimentAnlys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Flatten

# %%
# Load dataset (top 5000 words)
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=5000)
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
word_index = imdb.get_word_index()
reverse_word_index = {value: key for key, value in word_index.items()}

def decode_review(text):
    return ' '.join([reverse_word_index.get(i - 3, '?') for i in text])
# Out:
# ...
# 1641221/1641221 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
x_train = pad_sequences(x_train, maxlen=100)
x_test = pad_sequences(x_test, maxlen=100)
x_train = np.array(x_train).astype(np.int32)
x_test = np.array(x_test).astype(np.int32)

# %%
model = Sequential()

model.add(Embedding(5000, 32))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=3)
# Out:
# Epoch 1/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7561 - loss: 0.4920
# Epoch 2/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8834 - loss: 0.2807
# Epoch 3/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9320 - loss: 0.1917

# %%
loss, acc = model.evaluate(x_test, y_test)
print("Accuracy:", acc)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8470 - loss: 0.3477
# Accuracy: 0.8469600081443787

# %%
pred = model.predict(x_test)
for i in range(5):
    print("\n===================================")

    print("REVIEW:")
    print(decode_review(x_test[i])[:150])

    print("\nACTUAL RESULT:")
    if y_test[i] == 1:
        print("Positive 😊 ")
    else:
        print("Negative 😞")

    print("\nMODEL PREDICTION:")
    if pred[i] > 0.5:
        print("Positive 😊")
    else:
        print("Negative 😞")
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# ...
# REVIEW:
# ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? please give this one a miss br br ? ? and the rest of the cast ? terrible performanc
#
# ACTUAL RESULT:
# Negative 😞
#
# MODEL PREDICTION:
# Negative 😞
#
# ...
# REVIEW:
# a powerful study of ? sexual ? and desperation be patient ? up the atmosphere and pay attention to the wonderfully written script br br i praise rober
#
# ACTUAL RESULT:
# Positive 😊
#
# MODEL PREDICTION:
# Positive 😊
#
# ...
# REVIEW:
# the ? of that ? ? civil war it would be easy to see this as a ? about those events ? may or may not have had ? ? in mind when he made ? but whatever ?
#
# ACTUAL RESULT:
# Positive 😊
#
# MODEL PREDICTION:
# Positive 😊
#
# ...
# REVIEW:
# the mother in this movie is ? with her children to the point of ? i wish i wasn't so angry about her and her actions because i would have otherwise en
#
# ACTUAL RESULT:
# Negative 😞
#
# MODEL PREDICTION:
# Negative 😞
#
# ...
# REVIEW:
# ...
